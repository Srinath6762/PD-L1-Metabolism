# %%
# importing required packages
import magic
import scprep
import os
os.chdir("D:\Teams")

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
# loading required data

emt_data = scprep.io.load_tsv("Single-cell_RNA-seq_Read_Count.txt")
emt_data = emt_data.T
#emt_data = emt_data.drop(['Gene'], axis=1)
emt_data.head()
# Out:
# ID           ENSMUSG00000000001  ENSMUSG00000000003  ENSMUSG00000000028  \
# E10.5D_1_01               241.0                 0.0               185.0
# E10.5D_1_02               313.0                 0.0                29.0
# E10.5D_1_03               193.0                 0.0               153.0
# E10.5D_1_04               217.0                 0.0               170.0
# E10.5D_1_05               346.0                 0.0                49.0
#
# ID           ENSMUSG00000000031  ENSMUSG00000000037  ENSMUSG00000000049  \
# E10.5D_1_01               685.0                 0.0                 3.0
# E10.5D_1_02               842.0                 0.0                 1.0
# E10.5D_1_03               552.0                18.0                11.0
# E10.5D_1_04               503.0                 0.0                 1.0
# E10.5D_1_05               423.0                 0.0                 4.0
#
# ID           ENSMUSG00000000056  ENSMUSG00000000058  ENSMUSG00000000078  \
# ...

# %%
scprep.plot.plot_library_size(emt_data, cutoff=1500)
# Out:
# <AxesSubplot:xlabel='Library size', ylabel='Number of cells'>

# %%
emt_data = scprep.normalize.library_size_normalize(emt_data)
# be sure to uncomment this, unless your data is pre-transformed
emt_data.head()
# Out:
# ID           ENSMUSG00000000001  ENSMUSG00000000003  ENSMUSG00000000028  \
# E10.5D_1_01            2.516648                 0.0            1.931867
# E10.5D_1_02            2.903075                 0.0            0.268975
# E10.5D_1_03            1.899651                 0.0            1.505941
# E10.5D_1_04            1.879810                 0.0            1.472662
# E10.5D_1_05            3.092038                 0.0            0.437890
#
# ID           ENSMUSG00000000031  ENSMUSG00000000037  ENSMUSG00000000049  \
# E10.5D_1_01            7.153128             0.00000            0.031328
# E10.5D_1_02            7.809551             0.00000            0.009275
# E10.5D_1_03            5.433199             0.17717            0.108270
# E10.5D_1_04            4.357348             0.00000            0.008663
# E10.5D_1_05            3.780151             0.00000            0.035746
#
# ID           ENSMUSG00000000056  ENSMUSG00000000058  ENSMUSG00000000078  \
# ...

# %%
magic_op = magic.MAGIC()

# %%
emt_magic = magic_op.fit_transform(emt_data)
# Out:
# Calculating MAGIC...
#   Running MAGIC on 529 cells and 40916 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
# C:\Users\Neel\AppData\Roaming\Python\Python38\site-packages\magic\magic.py:425: UserWarning: Input matrix contains unexpressed genes. Please remove them prior to running MAGIC.
#   warnings.warn(
#     Calculated PCA in 1.86 seconds.
#     Calculating KNN search...
#     Calculated KNN search in 0.04 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.03 seconds.
#   Calculated graph and diffusion operator in 2.00 seconds.
#   Running MAGIC with `solver='exact'` on 40916-dimensional data may take a long time. Consider denoising specific genes with `genes=<list-like>` or using `solver='approximate'`.
#   Calculating imputation...
#   Calculated imputation in 0.51 seconds.
# Calculated MAGIC in 2.68 seconds.

# %%
emt_magic = emt_magic.T

# %%
emt_magic.head()
# Out:
#                     E10.5D_1_01  E10.5D_1_02  E10.5D_1_03  E10.5D_1_04  \
# ID
# ENSMUSG00000000001     2.355079     2.524697     2.642810     2.621933
# ENSMUSG00000000003     0.000000     0.000000     0.000000     0.000000
# ENSMUSG00000000028     0.609787     0.823532     0.943355     0.776785
# ENSMUSG00000000031    15.068633     8.140734     6.143570     6.270666
# ENSMUSG00000000037     0.022850     0.040357     0.048585     0.038850
#
#                     E10.5D_1_05  E10.5D_1_06  E10.5D_1_07  E10.5D_1_08  \
# ID
# ENSMUSG00000000001     2.607974     2.503365     2.467482     2.661508
# ENSMUSG00000000003     0.000000     0.000000     0.000000     0.000000
# ENSMUSG00000000028     0.814624     0.850200     0.708570     0.942089
# ENSMUSG00000000031     5.732338     6.963871    10.636606     6.400078
# ENSMUSG00000000037     0.037788     0.041736     0.024743     0.048976
#
#                     E10.5D_1_09  E10.5D_1_10  ...   UE_4_01    UE_4_02  \
# ...

# %%
emt_magic = emt_magic.round(5)
emt_magic.to_csv("GSE90047_MAGIC.tsv",sep="\t")
